# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('main_theme')

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y, label = 'first')
plt.scatter(np.random.rand(100), np.random.rand(100), label = 'second')
plt.legend()
plt.xlabel('X label')
plt.show()
